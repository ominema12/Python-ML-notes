# %% [markdown]
# # Linear Regression

# %%
# Y(dependent)=mx(Independent)+c -->TElls relationshipm b/w two variables(independent and dependent)
#Find the best fit lin eonly throught the data points

# %%
# continous 1,23,4,5,6,6 (Regression)-Linear Regression
# categorial 'Delhi','Mumbai','India' ; #(classification) #Logistic Regression

# %%
#dependent variable should be continous

# %%
#linear used to predict the cont dependent varaible using a given set of independent variables.
#Logistics used to predict the categorial dependent variables using a given set of independent variables.(Binary classification)
#classification (Logistics)

# %%
from IPython.display import Image
Image(filename='C:\\Users\\HP\\OneDrive\\Pictures\\Screenshots\\Screenshot_20230222_024823.png')

# %%
 from IPython.display import Image
Image(filename='C:\\Users\\HP\\OneDrive\\Pictures\\Screenshots\\Screenshot (23).png')

# %% [markdown]
# # KNN

# %%
import numpy as np #linear algebra
